# %% [markdown]
# # Updating Data Frames
#
# ## Data: Palmer Penguins

# %%
# standard libraries
import pandas as pd
import numpy as np

# import seaborn with its standard abbreviation
import seaborn as sns

# will use the random library to create some random numbers 
import random

# %%
# import data from seaborn
penguins = sns.load_dataset('penguins')

# look at data frame's head
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## Adding A Column
# General syntax to add a single column is
# ```
# df['new_column_name'] = new_column_values
# ```
#
# `new_column_values` could be:
# - a `pd.Series` or `numpy.array` of the same length as the data frame
# - a single scalar (a single number, a single string)
#
# **Example**
#
# Want to create a new column where the body mass is in kg instead of grams

# %%
penguins['body_mass_kg'] = penguins.body_mass_g/1000

print('body_mass_kg' in penguins.columns)
# Out:
# True

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  body_mass_kg
# 0       3750.0    Male          3.75
# 1       3800.0  Female          3.80
# 2       3250.0  Female          3.25
# 3          NaN     NaN           NaN
# 4       3450.0  Female          3.45

# %% [markdown]
# To create a new column and insert it at a particular position we use `insert()`:
# ```
# df.insert(loc = integers_index,
#         column = 'new_column_name',
#         value = new_col_values) # location of new column
# ```
# - insert modifies the data frame in place so you cannot override the data frame by assigning the function to it because it will return `nothing` which is a `NoneType`
#
# **Example**
# Suppose each penguins gets a unique code as a 3 digit number, Add this column at the beginning of the data frame

# %%
#create random 3-digit codes
# sample is without replacement
codes = random.sample( range(100, 1000), len(penguins) )
penguins.insert(loc=0,
               column = 'code',
               value = codes)

# %%
penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   738  Adelie  Torgersen            39.1           18.7              181.0
# 1   223  Adelie  Torgersen            39.5           17.4              186.0
# 2   474  Adelie  Torgersen            40.3           18.0              195.0
# 3   221  Adelie  Torgersen             NaN            NaN                NaN
# 4   269  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  body_mass_kg
# 0       3750.0    Male          3.75
# 1       3800.0  Female          3.80
# 2       3250.0  Female          3.25
# 3          NaN     NaN           NaN
# 4       3450.0  Female          3.45

# %% [markdown]
# ## Adding Multiple Columns
#
# We can assign multiple columns in the same call using the `assign()` method.
#
# Syntax:
# ```
# df.assign(new_col1_name = new_col1_values,
#         new_col2_name = new_col2_values)
# ```
# Notice: new column names are not strings, we declare them as if we were creating variables
#
# **Example**
# Add columns
#
# - flipper length converted from mm to cm
# - a code representing the observer

# %%
# create codes for observers
observers = random.choices(['A', 'B', 'C'], # sample from this array
                        k=len(penguins)) # get this/these many items
penguins = penguins.assign(flipper_length_cm = penguins.flipper_length_mm/10,
                          observer = observers
                          )
penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   738  Adelie  Torgersen            39.1           18.7              181.0
# 1   223  Adelie  Torgersen            39.5           17.4              186.0
# 2   474  Adelie  Torgersen            40.3           18.0              195.0
# 3   221  Adelie  Torgersen             NaN            NaN                NaN
# 4   269  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  body_mass_kg  flipper_length_cm observer
# 0       3750.0    Male          3.75               18.1        C
# 1       3800.0  Female          3.80               18.6        B
# 2       3250.0  Female          3.25               19.5        C
# 3          NaN     NaN           NaN                NaN        C
# 4       3450.0  Female          3.45               19.3        B

# %% [markdown]
# ## Removing Columns
# We can remove columns using the `drop()` method.
#
# Syntax:
# ```
# df = df.drop(columns=col_names)
# ```
# where `col_names` can be a single column (string) or a list of column names
#
# **Example**
#
# We want to drop the flipper length in mm and the body mass in grams

# %%
# df is reassigned when using drop
penguins = penguins.drop(columns=['flipper_length_mm', 'body_mass_g'])

print(penguins.columns)
# Out:
# Index(['code', 'species', 'island', 'bill_length_mm', 'bill_depth_mm', 'sex',
#        'body_mass_kg', 'flipper_length_cm', 'observer'],
#       dtype='object')

# %% [markdown]
# ## Updating Values
#
# Sometimes we want to update certain values in our data frame.
#
# ### A single value
# We can access a single value in a `pd.DataFrame` using the locators:
#
# -`at[]` : to select by labels
# -`iat[]` : to select by integer index/position
#
# Syntax for `at[]` :
# ```
# df.at[single_index_value, 'column_name']
# ```
# `at[]` equivalent to `loc[]` when accessing a single value
#
# **Example**
# Want to know the bill length of the penguin in the fourth row

# %%
# uses indexing so row 4 technically
penguins.at[3, 'bill_length_mm']
# Out:
# nan

# %% [markdown]
# We got an NA. Let's update this to 38.3 mm. We do this using `[at]` too

# %%
# update
penguins.at[3, 'bill_length_mm'] = 38.3

penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm     sex  \
# 0   738  Adelie  Torgersen            39.1           18.7    Male
# 1   223  Adelie  Torgersen            39.5           17.4  Female
# 2   474  Adelie  Torgersen            40.3           18.0  Female
# 3   221  Adelie  Torgersen            38.3            NaN     NaN
# 4   269  Adelie  Torgersen            36.7           19.3  Female
#
#    body_mass_kg  flipper_length_cm observer
# 0          3.75               18.1        C
# 1          3.80               18.6        B
# 2          3.25               19.5        C
# 3           NaN                NaN        C
# 4          3.45               19.3        B

# %%
# best practice to not update columns by indexing in case columns change
penguins.iat[1, 0] = 999

penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm     sex  \
# 0   738  Adelie  Torgersen            39.1           18.7    Male
# 1   999  Adelie  Torgersen            39.5           17.4  Female
# 2   474  Adelie  Torgersen            40.3           18.0  Female
# 3   221  Adelie  Torgersen            38.3            NaN     NaN
# 4   269  Adelie  Torgersen            36.7           19.3  Female
#
#    body_mass_kg  flipper_length_cm observer
# 0          3.75               18.1        C
# 1          3.80               18.6        B
# 2          3.25               19.5        C
# 3           NaN                NaN        C
# 4          3.45               19.3        B

# %% [markdown]
# ## Update Multiple Values in a Column
#
# ### By Condition
#
# Think of `case_when` in R.
#
# **Example**
#
# We want to classify penguins such that:
#
# - small penguins : body mass < 3 kg
# - medium penguins : body mass 3 kg <= body mass < 5 kg
# - big penguins : body mass > 5kg
#
# One way to do this is using `numpy.select()` to create a new column

# %%
# create a list with the condition
conditions = [penguins.body_mass_kg < 3,
             (3 <=penguins.body_mass_kg) & (penguins.body_mass_kg<5),
             5 <= penguins.body_mass_kg]

# create a list with the choices
choices = ['small',
          'medium',
          'large']

# default = value for anything that falls outside of conditions
penguins['size'] = np.select(conditions, choices, default=np.nan)

penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm     sex  \
# 0   738  Adelie  Torgersen            39.1           18.7    Male
# 1   999  Adelie  Torgersen            39.5           17.4  Female
# 2   474  Adelie  Torgersen            40.3           18.0  Female
# 3   221  Adelie  Torgersen            38.3            NaN     NaN
# 4   269  Adelie  Torgersen            36.7           19.3  Female
#
#    body_mass_kg  flipper_length_cm observer    size
# 0          3.75               18.1        C  medium
# 1          3.80               18.6        B  medium
# 2          3.25               19.5        C  medium
# 3           NaN                NaN        C     nan
# 4          3.45               19.3        B  medium

# %% [markdown]
# ### Update a column by selecting values
#
# Sometimes we just want to update a few values that satisfy a condition.
#
# We can do this by selecting data using `loc[]` if selecting by label, and then assigning a new value
# ```
# df.loc[row_selection, col_name] = new_values
# ```
#
# where
# -`row_selection` = rows we want to update
# -`col_names` = a single column name
# -`new_values` = the new value or values we want to update. If using multiple values, make sure they are the same length as the data frame
#
# **Example**
# We want to update the "Male" value in the sex column to "M"

# %%
# selecting rows with Males in Sex column
penguins.loc[penguins.sex=='Male', 'sex'] = 'M'

# %%
penguins.sex.unique()
# Out:
# array(['M', 'Female', nan], dtype=object)

# %% [markdown]
# ## `SettingWithCopyWarning`
#
# Suppose we want to update the "Female" value in the sex column to "F".
# This is an example of something we might want to try but won't work

# %%
# selecting rows with Males in Sex column
penguins[penguins.sex=='Female']['sex'] = 'F'

# %% [markdown]
# When we select data with **chained indexing** [] [] instead of `loc` we get a warning. `pandas` is trying to alert us that our code is ambigious. In this case, we did not update the penguins data frame:

# %%
penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm  sex  body_mass_kg  \
# 0   738  Adelie  Torgersen            39.1           18.7    M          3.75
# 1   999  Adelie  Torgersen            39.5           17.4    F          3.80
# 2   474  Adelie  Torgersen            40.3           18.0    F          3.25
# 3   221  Adelie  Torgersen            38.3            NaN  NaN           NaN
# 4   269  Adelie  Torgersen            36.7           19.3    F          3.45
#
#    flipper_length_cm observer    size
# 0               18.1        C  medium
# 1               18.6        B  medium
# 2               19.5        C  medium
# 3                NaN        C     nan
# 4               19.3        B  medium

# %% [markdown]
# ## Views and Copies
#
# Some `pandas` operation return a view to your data, while others return a copy to your data.
#
# - **Views** are actual subsets of the original data, when we update them, we are modifying the original data frame.
# - **Copies** are unique objects, independent of our original data frame. When we update a copy we are not modifying our original data frame.
#
# Depending on what we are trying to do we might want to modify the original data frame or we might want to modify a copy.
#
# ### Another `SettingWithCopyWarning`
#
# Another common situation when this warning comes up is when we try updating a subset of our data frame already stored in a variable
#
# **Example**
# We only want data from Biscoe island and after doing some analyses we want to add a new column to it

# %%
biscoe = penguins[penguins.island=='Biscoe']

# 50 lines of code

biscoe['sample_column'] = 100
# Out:
# /tmp/ipykernel_8268/3682940859.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biscoe['sample_column'] = 100

# %% [markdown]
# Essentially what we did was
# ```python
# penguins[penguins.island=='Biscoe']['sample_column'] = 100
# ```
#
# To fix this we can **take control of the copy-view situation and explicitely ask for a copy of the dataset when subsetting the data**. Use the `copy()` method for this.

# %%
biscoe = penguins[penguins.island=='Biscoe'].copy()

biscoe['sample_col'] = 100

biscoe.head()
# Out:
#     code species  island  bill_length_mm  bill_depth_mm sex  body_mass_kg  \
# 20   907  Adelie  Biscoe            37.8           18.3   F          3.40
# 21   431  Adelie  Biscoe            37.7           18.7   M          3.60
# 22   812  Adelie  Biscoe            35.9           19.2   F          3.80
# 23   264  Adelie  Biscoe            38.2           18.1   M          3.95
# 24   760  Adelie  Biscoe            38.8           17.2   M          3.80
#
#     flipper_length_cm observer    size  sample_col
# 20               17.4        A  medium         100
# 21               18.0        B  medium         100
# 22               18.9        A  medium         100
# 23               18.5        B  medium         100
# 24               18.0        A  medium         100

# %%
penguins.head()
# Out:
#    code species     island  bill_length_mm  bill_depth_mm  sex  body_mass_kg  \
# 0   738  Adelie  Torgersen            39.1           18.7    M          3.75
# 1   999  Adelie  Torgersen            39.5           17.4    F          3.80
# 2   474  Adelie  Torgersen            40.3           18.0    F          3.25
# 3   221  Adelie  Torgersen            38.3            NaN  NaN           NaN
# 4   269  Adelie  Torgersen            36.7           19.3    F          3.45
#
#    flipper_length_cm observer    size
# 0               18.1        C  medium
# 1               18.6        B  medium
# 2               19.5        C  medium
# 3                NaN        C     nan
# 4               19.3        B  medium
